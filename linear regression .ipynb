# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("HousingData.csv")

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]>

# %%
data.fillna(0, inplace=True)

# %%
y = data[["MEDV"]]
x = data[["RM"]]
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state=0)

# %%
plt.scatter(x_train, y_train, color = 'Red')
plt.title('MEDV vs RM')
plt.xlabel('RM')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %%
model = LinearRegression()
linear_regression = model.fit(x_train,y_train)
plt.scatter(x_train, y_train,  color='green')
plt.plot(x_train, linear_regression.predict(x_train), color='black')
plt.title('MEDV vs RM')
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.show()

# %%
y_pred = linear_regression.predict(x_test)
plt.scatter(x_test, y_test,  color='blue')
plt.plot(x_test, y_pred, color='black')
plt.title('predicted MEDV vs RM')
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.show()

# %%
print('MSE:', mean_squared_error(y_test, y_pred), 'R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 46.90735162739531 R2: 0.42394386816456286

# %%
y = data[["MEDV"]]
x = data[["PTRATIO"]]
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state=0)

# %%
plt.scatter(x_train, y_train, color = 'Red')
plt.title('MEDV vs PTRATIO')
plt.xlabel('PTRATIO')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %%
model = LinearRegression()
linear_regression = model.fit(x_train,y_train)
plt.scatter(x_train, y_train,  color='green')
plt.plot(x_train, linear_regression.predict(x_train), color='black')
plt.title('MEDV vs PTRATIO')
plt.xlabel('PTRATIO')
plt.ylabel('MEDV')
plt.show()

# %%
y_pred = linear_regression.predict(x_test)
plt.scatter(x_test, y_test,  color='blue')
plt.plot(x_test, y_pred, color='black')
plt.title('predicted MDEV vs PTRATIO')
plt.xlabel('PTRATIO')
plt.ylabel('MDEV')
plt.show()

# %%
print('MSE:', mean_squared_error(y_test, y_pred), 'R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 81.79497121208001 R2: -0.004501279336843522

# %%
y = data[["MEDV"]]
x = data[["LSTAT"]]
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state=0)

# %%
plt.scatter(x_train, y_train, color = 'Red')
plt.title('MEDV vs LSTAT')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %%
model = LinearRegression()
linear_regression=model.fit(x_train,y_train)
plt.scatter(x_train, y_train,  color='red')
plt.plot(x_train, linear_regression.predict(x_train), color='black')
plt.title('MEDV vs LSTAT')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()

# %%
y_pred = linear_regression.predict(x_test)
plt.scatter(x_test, y_test,  color='green')
plt.plot(x_test, y_pred, color='black')
plt.title('predicted MEDV vs LSTAT')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()

# %%
print('MSE:', mean_squared_error(y_test, y_pred), 'R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 46.085785730535534 R2: 0.43403329031638926

# %%
x=data[['RM','PTRATIO']]
y=data['MEDV']
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state=0)
model = LinearRegression()
linear_regression =model.fit(x_train,y_train)
y_pred = linear_regression.predict(x_test)
print('MSE:', mean_squared_error(y_test, y_pred), 'R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 49.47074100205858 R2: 0.3924635966010288

# %%
x=data[['RM','LSTAT']]

y=data['MEDV']

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state=0)

model = LinearRegression()

linear_regression = model.fit(x_train,y_train)

y_pred = linear_regression.predict(x_test)

print('MSE:', mean_squared_error(y_test, y_pred), 'R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 36.620446428690805 R2: 0.5502744882429451

# %%
x=data[['PTRATIO','LSTAT']]

y=data['MEDV']

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state=0)

model = LinearRegression()

linear_regression=model.fit(x_train,y_train)

y_pred = linear_regression.predict(x_test)

print('MSE:', mean_squared_error(y_test, y_pred), 'R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 52.457427484041524 R2: 0.3557849310587289

# %%
x=data[['RM', 'LSTAT', 'PTRATIO']]

y=data['MEDV']

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state=0)

model = LinearRegression()

linear_regression=model.fit(x_train,y_train)

y_pred = linear_regression.predict(x_test)

print('MSE:', mean_squared_error(y_test, y_pred), 'R2:', r2_score(y_test, y_pred))
# Out:
# MSE: 41.392847660986924 R2: 0.4916659567854246
